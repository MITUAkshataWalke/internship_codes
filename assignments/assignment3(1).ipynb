# %%
# 1. Create a class BankAccount with the following:
# a) Attributes: account_holder, account_number, and balance.
# b) Methods: deposit(amount), withdraw(amount), and get_balance().
# c) withdraw() should print a message and do nothing if the amount exceeds the current balance.
# d) A __str__ method that returns a readable summary of the account.
# Create two BankAccount objects and perform a few deposits and withdrawals on each
class BankAccount:
    def __init__(self,account_holder,account_number,balance):
        self.account_holder=account_holder
        self.account_number=account_number
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(amount,"deposited successfully")
    def withdraw(self,amount):
        if self.balance>amount:
            self.balance-=amount
            print(amount,"withdrawn successfully")
        else:
            print("insufficient balance")
    def get_balance(self):
        print(self.balance)
    def __str__ (self):
        return(f"account holder:{self.account_holder}\naccount number:{self.account_number}\nbalance:{self.balance}")
acc1=BankAccount("akshata",1001,12000)
acc2=BankAccount("shreya",1002,13000)

# %%
print(acc1)
# Out:
# account holder:akshata
# account number:1001
# balance:12000

# %%
print(acc2)
# Out:
# account holder:shreya
# account number:1002
# balance:13000

# %%
acc1.deposit(1000)
acc2.deposit(2000)
# Out:
# 1000 deposited successfully
# 2000 deposited successfully

# %%
acc1.withdraw(100)
acc2.withdraw(300)
# Out:
# 100 withdrawn successfully
# 300 withdrawn successfully

# %%
acc1.balance
# Out:
# 12900

# %%
acc2.balance
# Out:
# 14700

# %%
# 2. Create a class Student with attributes name, roll_no, and marks (a list of 5 subject marks). Add
# methods:
# a) calculate_percentage() — returns the average of all marks.
# b) get_grade() — returns 'A' for >= 80, 'B' for >= 60, 'C' for >= 40, and 'Fail' otherwise.
# c) display() — prints all details including percentage and grade.
# Create a list of 3 Student objects and call display() on each.
class Student:
    def __init__ (self,name,roll_no,marks):
        self.name=name
        self.roll_no=roll_no
        self.marks=marks
    def calculate_percentage(self):
        return sum(self.marks)/len(self.marks)
        
    def get_grade(self):
        percentage=self.calculate_percentage()
        if percentage>=80:
           return("A")
        elif percentage>=60:
            return("B")
        elif percentage>=40:
            return("C")
        else:
            return("Fail")
    def display(self):
        return(f"name:{self.name}\nroll_no:{self.roll_no}\nmarks:{self.marks}\npercentage:{self.calculate_percentage()}\ngrade:{self.get_grade()}")
s1=Student("akshata",1,[12,23,34,45,56])
s2=Student("ishita",2,[90,78,98,56,74])
s3=Student("asmita",3,[45,67,43,78,65])

# %%
print(s1.display())
# Out:
# name:akshata
# roll_no:1
# marks:[12, 23, 34, 45, 56]
# percentage:34.0
# grade:Fail

# %%
print(s2.display())
# Out:
# name:ishita
# roll_no:2
# marks:[90, 78, 98, 56, 74]
# percentage:79.2
# grade:B

# %%
print(s3.display())
# Out:
# name:asmita
# roll_no:3
# marks:[45, 67, 43, 78, 65]
# percentage:59.6
# grade:C

# %%
# 3. Create a class Employee with private attributes __name, __emp_id, and __salary. Add:
# a) Getter and setter methods for all three attributes.
# b) The salary setter should raise a ValueError if the value is below 10000.
# c) A method give_raise(percent) that increases salary by the given percentage.
# Demonstrate that the private attributes cannot be accessed directly, and that all access goes
# through the methods.
class Employee():
    def __init__ (self,name,emp_id,salary):
        self.__name=name
        self.__emp_id=emp_id
        self.__salary=salary
    def get_name(self):
        return self.__name
    def get_emp_id(self):
        return self.__emp_id
    def get_salary(self):
        return self.__salary
    def set_name(self,name):
        self.__name=name
    def set_emp_id(self,emp_id):
        self.__emp_id=emp_id
    def set_salary(self,salary):
        if salary<10000:
            raise ValueError('salary should be greater than 10000')
        self.__salary=salary
    def give_raise(self,percent):
        self.__salary=self.__salary+(self.__salary*percent/100)
e1=Employee("akshata",101,20000)
print("Name:",e1.get_name())
print("Id:",e1.get_emp_id())
print("Salary:",e1.get_salary())
e1.give_raise(10)
print("salary after raise:",e1.get_salary())
e1.set_salary(25000)
print("updated salary:",e1.get_salary())
try:
    print(e1.__salary)
except AttributeError:
    print("Cannot access private attributes directly")
# Out:
# Name: akshata
# Id: 101
# Salary: 20000
# salary after raise: 22000.0
# updated salary: 25000
# Cannot access private attributes directly

# %%
# 4. Build a class SecureVault that stores a private __pin and a private __data dictionary. It should
# have:
# a) A method add_entry(pin, key, value) that adds to __data only if the pin matches.
# b) A method get_entry(pin, key) that returns the value only if the pin matches.
# c) Any wrong pin attempt should print 'Access Denied' and return nothing.
class SecureVault:
    def __init__ (self,pin):
        self.__pin=pin
        self.__data={}
    def add_entry(self,pin,key,value):
        if pin==self.__pin:
            self.__data[key]=value
        else:
            print("Access Denied")
    def get_entry(self,pin,key):
        if pin==self.__pin:
            return self.__data.get(key)
        else:
            print("access denied")
vault=SecureVault(1234)
vault.add_entry(1234,"name","akshata")
print(vault.get_entry(1234,"name"))
vault.add_entry(2344,"city","pune")
print(vault.get_entry(2344,"city"))
# Out:
# akshata
# Access Denied
# access denied
# None

# %%
# 5. Create a base class Shape with a method area() that returns 0 and a method describe() that
# prints 'I am a shape'. Create three subclasses:
# a) Circle(radius) — overrides area() using pi * r^2.
# b) Rectangle(length, width) — overrides area().
# c) Triangle(base, height) — overrides area().
# Each subclass should also override describe() to print something specific about itself. Create one
# object of each and call both methods.
class shape:
    def area(self):
        return 0
    def describe(self):
        print("i am a shape")
class circle(shape):
    def __init__ (self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    def describe(self):
        print("i am a circle")
class rectangle(shape):
    def __init__ (self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.length*self.width
    def describe(self):
        print("i am a rectangle")
class triangle(shape):
    def __init__ (self,base,height):
        self.base=base
        self.height=height
    def area(self):
        return 0.5*self.base*self.height
    def describe(self):
        print("i am a triangle")
c=circle(4)
r=rectangle(3,4)
t=triangle(5,6)
c.describe()
print("area:",c.area())
r.describe()
print("area:",r.area())
t.describe()
print("area:",t.area())
# Out:
# i am a circle
# area: 50.24
# i am a rectangle
# area: 12
# i am a triangle
# area: 15.0

# %%
# 6. Create a class Vehicle with attributes make, model, and year and a method start_engine() that
# prints 'Engine started'. Create two subclasses:
# a) Car(make, model, year, num_doors) — overrides start_engine() to include the car's name in
# the message.
# b) ElectricCar(make, model, year, battery_capacity) — overrides start_engine() to print 'Silent
# start — battery at X kWh'.
# Use super() in both subclasses to call the parent __init__. Create objects and test all methods.
class vehicle:
    def __init__ (self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
    def start_engine(self):
        print("engine started")
class car(vehicle):
    def __init__ (self,make,model,year,num_doors):
        super().__init__ (make,model,year)
        self.num_doors=num_doors
    def start_engine(self):
        print(f"engine started for{self.make} {self.model}")
class electricCar(vehicle):
    def __init__ (self,make,model,year,battery_capacity):
        super().__init__ (make,model,year)
        self.battery_capacity=battery_capacity
    def start_engine(self):
        print(f"silent start battery at {self.battery_capacity} kwh")
c1=car("toyatto","camry",2023,4)
e1=electricCar("tesla","model 3",2024,75)
print(c1.make,c1.model,c1.year,c1.num_doors)
c1.start_engine()
print(e1.make,e1.model,e1.year,e1.battery_capacity)
e1.start_engine()
# Out:
# toyatto camry 2023 4
# engine started fortoyatto camry
# tesla model 3 2024 75
# silent start battery at 75 kwh

# %%
# 7. Create a base class Animal with a method sound() that prints 'Some sound'. Create subclasses
# Dog, Cat, and Cow, each overriding sound() with their respective sounds. Write a function
# make_all_sounds(animals) that takes a list of Animal objects and calls sound() on each.
# Demonstrate that the correct method is called regardless of the object type.
class Animal:
    def sound(self):
        print("some sound")
class Dog(Animal):
    def sound(self):
        print("woof")
class Cat(Animal):
    def sound(self):
        print("meow")
class Cow(Animal):
    def sound(self):
        print("moo")
def make_all_sounds(animals):
        for animal in animals:
            animal.sound()
dog=Dog()
cat=Cat()
cow=Cow()
animals=[dog,cat,cow]
make_all_sounds(animals)
# Out:
# woof
# meow
# moo

# %%
# 8. Create a class Calculator with overloaded-style methods using default arguments:
# a) add(a, b, c=0) — adds two or three numbers.
# b) multiply(a, b, c=1) — multiplies two or three numbers.
# c) Also implement __add__ on a class Vector(x, y) so that two Vector objects can be added with
# the + operator. Print the resulting vector.
class Calculator:
    def add(self,a,b,c=0):
        return a+b+c
    def multiply(self,a,b,c=1):
        return a*b*c
class Vector:
    def __init__ (self,x,y):
        self.x=x
        self.y=y
    def __add__ (self,other):
        return Vector(self.x+other.x,self.y+other.y)
    def __str__ (self):
        return f"({self.x},{self.y})"
c=Calculator()
print("Addition of two numbers:",c.add(10,20))
print("addition of three numbers",c.add(10,20,30))
print("multiplication of two numbers:",c.multiply(10,20))
print("multiplication of three numbers:",c.multiply(10,20,30))
v1=Vector(10,20)
v2=Vector(30,40)
v3=v1+v2
print("resultant vector:",v3)
# Out:
# Addition of two numbers: 30
# addition of three numbers 60
# multiplication of two numbers: 200
# multiplication of three numbers: 6000
# resultant vector: (40,60)

# %%
# 9. Perform the following file operations. Use plain text files only.
# a) Write a list of 5 student names to a file students.txt, one name per line.
file = open("students.txt", "w")
file.write("Amit\n")
file.write("Priya\n")
file.write("Rahul\n")
file.write("Sneha\n")
file.write("Karan\n")
file.close()
print("Contents after writing 5 names:")
file = open("students.txt", "r")
print(file.read())
file.close()
# b) Read the file back and print each name with its line number.
print("Names with line numbers:")
file = open("students.txt", "r")
lines = file.readlines()
for i in range(len(lines)):
    print(i + 1, lines[i].strip())
file.close()
# c) Append two more names to the same file without overwriting existing content.
file = open("students.txt", "a")
file.write("Neha\n")
file.write("Rohit\n")
file.close()
print("Contents after appending:")
file = open("students.txt", "r")
print(file.read())
file.close()
# d) Read the final file and count the total number of students.
file = open("students.txt", "r")
lines = file.readlines()
print("Total Students =", len(lines))
file.close()
# e) Copy the contents of students.txt into a new file students_backup.txt.
file1 = open("students.txt", "r")
data = file1.read()
file1.close()
file2 = open("students_backup.txt", "w")
file2.write(data)
file2.close()
print("Backup file contents:")
file2 = open("students_backup.txt", "r")
print(file2.read())
file2.close()
# Out:
# Contents after writing 5 names:
# Amit
# Priya
# Rahul
# Sneha
# Karan
#
# Names with line numbers:
# 1 Amit
# 2 Priya
# 3 Rahul
# 4 Sneha
# 5 Karan
# Contents after appending:
# Amit
# Priya
# Rahul
# Sneha
# Karan
# Neha
# Rohit
#
# Total Students = 7
# Backup file contents:
# Amit
# Priya
# Rahul
# Sneha
# Karan
# Neha
# Rohit

# %%
# 10. Build a menu-driven Student Record Manager using OOP and file handling. The app should
# have a class StudentManager with the following menu options:
# 1. Add Student — takes name, roll number, and marks for 3 subjects.
# 2. View All — displays all stored students with their average marks.
# 3. Search Student — finds a student by roll number.
# 4. Delete Student — removes a student by roll number.
# 5. Save to File — writes all records to students_data.txt.
# 6. Load from File — reads records back from students_data.txt on startup.
# 7. Exit
# Requirements: use a class with a list as internal storage, handle invalid menu choices gracefully,
# and use a while loop to keep the menu running until the user chooses to exit.
class StudentManager:
    def __init__ (self):
        self.students=[]
    def add_Student(self):
        name=input("enter name:")
        roll=int(input("enter roll no:"))
        m1=float(input("enter Marks of subject one:"))
        m2=float(input("enter Marks of subject two:"))
        m3=float(input("enter Marks of subject three:"))
        self.students.append([roll,name,m1,m2,m3])
        print("student added successfully")
    def view_all(self):
        if(len(self.students))==0:
            print("no records found")
            return
        for s in self.students:
            avg=(s[2]+s[3]+s[4])/3
            print(f"roll:{s[0]}\nname:{s[1]}\naverage:{avg}\n")
    def search_students(self):
        roll=int(input("enter roll no to search:"))
        for s in self.students:
            if s[0]==roll:
                avg=(s[2]+s[3]+s[4])/3
                print("roll:",s[0])
                print("name:",s[1])
                print("average:",avg)
                return
        print("student not found")
    def delete_student(self):
        roll=int(input("enter roll number to delete:"))
        for s in self.students:
            if s[0]==roll:
                self.students.remove(s)
                print("student deleted")
                return
        print("student not found")
    def save_to_file(self):
        file=open("students_data.txt",'w')
        for s in self.students:
            file.write(f"{s[0]},{s[1]},{s[2]},{s[3]},{s[4]}\n")
        file.close()
        print("records saved successfully")
    def load_from_file(self):
        self.students=[]
        try:
            file=open("students_data.txt",'r')
            for line in file:
                data=line.strip().split(",")
                self.students.append([
                    int(data[0]),
                    data[1],
                    float(data[2]),
                    float(data[3]),
                    float(data[4])
                ])
            file.close()
        except FileNotFoundError:
            pass
manager=StudentManager()
manager.load_from_file()
while True:
    print("1.add student")
    print("2.view all")
    print("3.search student")
    print("4.delete student")
    print("5.save to file")
    print("6.load from file")
    print("7.exit")
    choice=int(input("enter a choice:"))
    if choice==1:
        manager.add_Student()
    elif choice==2:
        manager.view_all()
    elif choice==3:
        manager.search_students()
    elif choice==4:
        manager.delete_student()
    elif choice==5:
        manager.save_to_file()
    elif choice==6:
        manager.load_from_file()
    elif choice==7:
        manager.save_to_file()
        print("exiting program")
        break
    else:
        print("invalid choice")
# Out:
# 1.add student
# 2.view all
# 3.search student
# 4.delete student
# 5.save to file
# 6.load from file
# 7.exit
# enter a choice: 2
# roll:101
# name:akshata
# average:81.33333333333333
#
# roll:101
# name:akshata
# average:92.33333333333333
#
# 1.add student
# 2.view all
# 3.search student
# 4.delete student
# 5.save to file
# 6.load from file
# 7.exit
# enter a choice: 3
# enter roll no to search: 101
# roll: 101
# name: akshata
# average: 81.33333333333333
# 1.add student
# 2.view all
# 3.search student
# 4.delete student
# 5.save to file
# 6.load from file
# 7.exit
# enter a choice: 4
# enter roll number to delete: 101
# student deleted
# 1.add student
# 2.view all
# 3.search student
# 4.delete student
# 5.save to file
# 6.load from file
# 7.exit
# enter a choice: 5
# records saved successfully
# 1.add student
# 2.view all
# 3.search student
# 4.delete student
# 5.save to file
# 6.load from file
# 7.exit
# enter a choice: 6
# 1.add student
# 2.view all
# 3.search student
# 4.delete student
# 5.save to file
# 6.load from file
# 7.exit
# enter a choice: 7
# records saved successfully
# exiting program
