# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\student3.csv")
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.shape
# Out:
# (16, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
df['name']=df['name'].str.title()

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 9      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    be   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df['class']
# Out:
# 0      TE
# 1      TE
# 2      BE
# 3      TE
# 4      TE
# 5      BE
# 6      BE
# 7      be
# 8      TE
# 9      TE
# 10     BE
# 11     TE
# 12     TE
# 13     be
# 14    NaN
# 15     TE
# Name: class, dtype: object

# %%
df['class']=df['class'].str.upper()

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 4      5     Asha    TE   63.28   NaN
# 5      6   Ayesha    BE     NaN  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    BE   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 9      9     Amol    TE   56.75  20.0
# 10    10    Anmol    BE   78.66   NaN
# 11    11   Surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    BE   88.45  21.0
# 14    14   Sachin   NaN   59.33  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df['marks']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.columns=df.columns.str.strip()

# %%
df['marks']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.count()
# Out:
# roll     15
# name     15
# class    14
# marks    13
# age      13
# dtype: int64

# %%
df.isnull().sum()
# Out:
# roll     0
# name     0
# class    1
# marks    2
# age      2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(5)

# %%
df.dropna()
# Out:
#     roll     name class     marks   age
# 0      1     Anil    TE  0.252311  22.0
# 1      2     Amit    TE  0.265644  21.0
# 2      3   Aniket    BE  0.341689  19.0
# 3      4  Ajinkya    TE  0.309600  20.0
# 6      7     Amar    BE  0.290400  19.0
# 7      8    Amita    BE  0.303689  23.0
# 8      9     Amol    TE  0.252222  20.0
# 12    12    Sujay    TE  0.329422  22.0
# 13    13  Subhash    BE  0.393111  21.0
# 15    15  Shalini    TE  0.282000  20.0

# %%
df['marks'].fillna(45)
# Out:
# 0      0.252311
# 1      0.265644
# 2      0.341689
# 3      0.309600
# 4      0.281244
# 5     45.000000
# 6      0.290400
# 7      0.303689
# 8      0.252222
# 10     0.349600
# 11    45.000000
# 12     0.329422
# 13     0.393111
# 14     0.263689
# 15     0.282000
# Name: marks, dtype: float64

# %%
df['marks'].fillna(df['marks'].mean())
# Out:
# 0     0.252311
# 1     0.265644
# 2     0.341689
# 3     0.309600
# 4     0.281244
# 5     0.301125
# 6     0.290400
# 7     0.303689
# 8     0.252222
# 10    0.349600
# 11    0.301125
# 12    0.329422
# 13    0.393111
# 14    0.263689
# 15    0.282000
# Name: marks, dtype: float64

# %%
# Out:
# 0     0.252311
# 1     0.265644
# 2     0.341689
# 3     0.309600
# 4     0.281244
# 5          NaN
# 6     0.290400
# 7     0.303689
# 8     0.252222
# 10    0.349600
# 11         NaN
# 12    0.329422
# 13    0.393111
# 14    0.263689
# 15    0.282000
# Name: marks, dtype: float64

# %%
df['age'].fillna(df['age'].median())
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     21.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 10    21.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df['class'].fillna(df['class'].mode()[0])
# Out:
# 0     TE
# 1     TE
# 2     BE
# 3     TE
# 4     TE
# 5     BE
# 6     BE
# 7     BE
# 8     TE
# 10    BE
# 11    TE
# 12    TE
# 13    BE
# 14    TE
# 15    TE
# Name: class, dtype: object

# %%
df.ffill()
# Out:
#     roll     name class     marks   age
# 0      1     Anil    TE  0.252311  22.0
# 1      2     Amit    TE  0.265644  21.0
# 2      3   Aniket    BE  0.341689  19.0
# 3      4  Ajinkya    TE  0.309600  20.0
# 4      5     Asha    TE  0.281244  20.0
# 5      6   Ayesha    BE  0.281244  20.0
# 6      7     Amar    BE  0.290400  19.0
# 7      8    Amita    BE  0.303689  23.0
# 8      9     Amol    TE  0.252222  20.0
# 10    10    Anmol    BE  0.349600  20.0
# 11    11   Surbhi    TE  0.349600  23.0
# 12    12    Sujay    TE  0.329422  22.0
# 13    13  Subhash    BE  0.393111  21.0
# 14    14   Sachin    BE  0.263689  21.0
# 15    15  Shalini    TE  0.282000  20.0

# %%
df.bfill(inplace=True)

# %%
df
# Out:
#     roll     name class     marks   age
# 0      1     Anil    TE  0.252311  22.0
# 1      2     Amit    TE  0.265644  21.0
# 2      3   Aniket    BE  0.341689  19.0
# 3      4  Ajinkya    TE  0.309600  20.0
# 4      5     Asha    TE  0.281244  20.0
# 5      6   Ayesha    BE  0.290400  20.0
# 6      7     Amar    BE  0.290400  19.0
# 7      8    Amita    BE  0.303689  23.0
# 8      9     Amol    TE  0.252222  20.0
# 10    10    Anmol    BE  0.349600  23.0
# 11    11   Surbhi    TE  0.329422  23.0
# 12    12    Sujay    TE  0.329422  22.0
# 13    13  Subhash    BE  0.393111  21.0
# 14    14   Sachin    TE  0.263689  21.0
# 15    15  Shalini    TE  0.282000  20.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([10,23,29,34,39,45,50])
y=np.array([14,21,31,43,48,55,58])
z=np.array([56,50,44,37,26,20,16])

# %%
plt.xlabel("x values")
plt.ylabel("y values")
plt.title("line chart:x vs y")
plt.plot(x,y,marker='o',mfc='red',ls="--");
plt.grid();

# %%
plt.xlabel("x values")
plt.ylabel("z values")
plt.title("line chart:x vs z")
plt.plot(x,z,marker="o",mfc='red',ls="--");
plt.grid();
